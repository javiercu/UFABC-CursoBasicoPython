# %% [markdown]
# ![photo.gif](attachment:photo.gif)

# %% [markdown]
# <html>
# <head>
#     <title>
#         UFABC-CursoBasicoPython
#     </title>
# </head>
# <body>
# <div class="row">
#   <div class="col-sm-2"><a href="http://lattes.cnpq.br/8400448405192982"><img src="photo.GIF" alt="some text" width=80 height=60 title = "Acessar Lattes: http://lattes.cnpq.br/8400448405192982"></a></div>
#   <div class="col-sm-4"><h3>Prof. Dr Javier Martinez Silva </h3></div>
# </div>
# <h2>Conteúdo do Cuso</h2>
#
# <ul>
#   <li><a href="Introducao.ipynb">Introdução</a><br></li>
#   <li><a href="Introducao.ipynb">Primeiros passos com o trabalho do notebook UFABC-Python</a></li>
#   <li><a href="InstalandoPython.ipynb">Instalando Python</a></li>
#   <li><a href="PrPmeirosPassos.ipynb">Primeiros passos: Hello, world!</a></li>
#   <li><a href="Variaveis.ipynb">Variáveis e Tipos de Dados</a></li>
#   <li><a href="">Expressões Booleanas</a>
#       <ul>
#           <li><a href=""> Tipo de dado "bool"</a></li>
#           <li><a href="">Operadores lógicos (and, or, not)</a></li>
#           <li><a href="">Precedência entre operadores relacionais, lógicos e aritméticos</a></li>
#       </ul>
#    </li>
#   <li><a href="">Execução Condicional (if, if..else, biblioteca math, exemplo)</a></li>
#   <li><a href="">Repetição com while</a></li>
#   <li><a href="">Variáveis Booleanas. Indicadores de Passagem</a></li> <!--Servem para indicar se uma determinada condição passou a ser verdadeira ou não, sendo usada em um laço de repetição-->
#   <li><a href="">Funções</a>
#        <ul>
#           <li><a href="">Definição</a></li>
#           <li><a href="">Criação e utilização de funções</a></li>
#           <li><a href="">Escopo de variável</a></li>
#       </ul>
#   </li>
#
#   <li><a href="">Testes Automatizados</a></li>
#   <li><a href="">Depurador (Funcionamento no contexto onde há várias funções)</a></li>
#   <li><a href="">Repetições Encaixadas</a></li>
#   <li><a href="">Lista</a>
#       <ul>
#           <li><a href="">Definição, sintaxe e índices</a></li>
#           <li><a href="">Comandos: len, type e append. </a></li>
#           <li><a href="">Manipulação de listas</a></li>
#       </ul>
#
#    </li>
#   <li><a href="">Manipulação de Listas </a>
#        <ul>
#           <li><a href="">Fatias de listas</a></li>
#           <li><a href="">Clonando listas </a></li>
#           <li><a href=""> Pertinência a uma lista</a></li>
#           <li><a href="">Concatenação (+)</a></li>
#           <li><a href="">Repetição (*) e remoção (del) de listas</a></li>
#       </ul>
#    </li>
# </ul>
# </body>
# </html>
