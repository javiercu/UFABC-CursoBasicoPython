# %% [markdown]
# O objetivo do presente notebook é introduzir os conceitos básicos de programação estruturada na linguagem Python. Apresentar as noções básicas e intermediárias sobre algoritmos.
#
# O Python é uma linguagem interpretada (não precisa de compilar), programas em execução (processos), ponteiros, alocação estática e dinâmica de memória, vetores e matrizes, funções e passagem de parâmetros, registros, arquivos e recursividade. Aplicar todos os conceitos apresentados no contexto da resolução de problemas clássicos e novos da computação.
#
# Alguns conceitos básicos importantes:
# Algoritmo = Uma lista de instruções passo a passo para resolver um problema dado (Pense como uma receita de bolo).
#
# O que é feito em Ciência da Computação?
#
# 1. Anaisar o problema
# 2. Criar um algoritmo que o resolva
# 3. Escrever um programa que implemente esse algoritmo
# 4. Testar o programa para verificar que realmente funciona
#
# É preciso conhecer alguma linguagem de programação: Linguagens formais, precisas e cujas instruções podem ser executadas por um computado (Python, Java, C/C++, Rugby, PHP, Javascript, entre outras).
#
# Linguagens Interpretadas tem a seguinte estrutura:
#
# ![Fig1.PNG](attachment:Fig1.PNG)
#
# Já as linguagens compiladas tem a seguinte estrutura:
#
# ![Fig2.PNG](attachment:Fig2.PNG)
#
#
#
# Linguagens interpretadas e compiladas:
#
# Exemplo (Java e Python)
#
# 1) Antes de iniciar a execução do programa, um compilador traduz o código fonte para "bycode" (código em bytes)
#
# 2) Ao iniciar a execução do programa, o interpretador lê os "bytecodes" um-a-um executando os comandos correspondentes.

# %% [markdown]
# <div class="row">
#   <div class="col-sm-4">Próxima Seção: <a> Instalando Python - Windows </a></div>
#   <div class="col-sm-4"><a> Ir ao Índice </a></div>
# </div>
